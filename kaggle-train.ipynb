# %%
#fill in here
pip install -r /kaggle/input/{your-dataset-name}/ChatGLM2-6B/requirements.txt

# %%
import os, sys 
#fill in here
path = "/kaggle/input/{your-dataset-name}/ChatGLM2-6B/ptuning"
retval = os.getcwd()
print("Working directory now: %s" % retval)
os.chdir( path )
retval = os.getcwd()
print("Successfully changed working directory: %s" % retval)

# %%
# !wandb off

# %%
# !bash train.sh
